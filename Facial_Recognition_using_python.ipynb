# %% [markdown]
# <a href="https://colab.research.google.com/github/akhil-roy/Internship-projects/blob/master/Facial_Recognition_using_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
face_classifier=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

def face_extractor(img):
    gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces=face_classifier.detectMultiScale(gray,1.3,5)

    if faces is():
        return None

    for(x,y,w,h) in faces:
        cropped_face =img[y:y+h,x:x+w]
    return cropped_face

cap=cv2.VideoCapture(0)
count=0

while True :
    _,frame=cap.read()

    if face_extractor(frame)is not None:
        count+=1
        face=cv2.resize(face_extractor(frame),(200,200))
        face=cv2.cvtColor(face,cv2.COLOR_BGR2GRAY)

        file_path='PATH/TO/DATA/user'+str(count)+'.jpg'
        cv2.imwrite(file_path,face)
        cv2.putText(face,str(count),(50,50),cv2.FONT_HERSHEY_COMPLEX,1,(0,255,0),2)
        cv2.imshow('FaceCropper',face)
    else:
        print("face not found")
        pass
    if cv2.waitKey(1)==13 or count==10:
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-4-5db489cf0602> in <module>()
#      20     _,frame=cap.read()
#      21
# ---> 22     if face_extractor(frame)is not None:
#      23         count+=1
#      24         face=cv2.resize(face_extractor(frame),(200,200))
#
# <ipython-input-4-5db489cf0602> in face_extractor(img)
#       4
#       5 def face_extractor(img):
# ----> 6     gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#       7     faces=face_classifier.detectMultiScale(gray,1.3,5)
#       8
#
# error: OpenCV(4.1.2) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
import cv2
import numpy as np
face_classifier=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

def face_extractor(img):
    gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces=face_classifier.detectMultiScale(gray,1.3,5)

    if faces is():
        return None

    for(x,y,w,h) in faces:
        cropped_face =img[y:y+h,x:x+w]
    return cropped_face

cap=cv2.VideoCapture(0)
count=0

while True :
    _,frame=cap.read()

    if face_extractor(frame)is not None:
        count+=1
        face=cv2.resize(face_extractor(frame),(200,200))
        face=cv2.cvtColor(face,cv2.COLOR_BGR2GRAY)

        file_path='PATH/TO/DATA/user'+str(count)+'.jpg'
        cv2.imwrite(file_path,face)
        cv2.putText(face,str(count),(50,50),cv2.FONT_HERSHEY_COMPLEX,1,(0,255,0),2)
        cv2.imshow('FaceCropper',face)
    else:
        print("face not found")
        pass
    if cv2.waitKey(1)==13 or count==10:
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-5-ec5c81f3b53c> in <module>()
#      20     _,frame=cap.read()
#      21
# ---> 22     if face_extractor(frame)is not None:
#      23         count+=1
#      24         face=cv2.resize(face_extractor(frame),(200,200))
#
# <ipython-input-5-ec5c81f3b53c> in face_extractor(img)
#       4
#       5 def face_extractor(img):
# ----> 6     gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#       7     faces=face_classifier.detectMultiScale(gray,1.3,5)
#       8
#
# error: OpenCV(4.1.2) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
import cv2
import numpy as np
from os import listdir
from os.path import isfile,join

data_path='PATH/TO/DATA/'
onlyfiles=[f for f in listdir(data_path)if isfile(join(data_path,f))]

Training_data,Labels=[],[]
for i,files in enumerate (onlyfiles):
    image_path=data_path+onlyfiles[i]
    images =cv2.cv2.imread(image_path,cv2.IMREAD_GRAYSCALE)
    Training_data.append(np.asarray(images,dtype=np.uint8))
    Labels.append(i)
Labels=np.asarray(Labels,dtype=np.int32)

model=cv2.face.LBPHFaceRecognizer_create()

model.train(Training_data,np.asarray(Labels))

print("Model Training complete")

face_classifier=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

def face_detector(img):
    gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces=face_classifier.detectMultiScale(gray,1.3,5)

    if faces is():
        return img,[]

    for(x,y,w,h) in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,255),2)
        roi=img[y:y+h,x:x+w]
        roi=cv2.resize(roi,(200,200))

    return img,roi

cap=cv2.VideoCapture(0)

while True :
    _,frame=cap.read()

    image,face=face_detector(frame)
    try:
        face=cv2.cvtColor(face,cv2.COLOR_BGR2GRAY)
        result=model.predict(face)

        if result[1]<500:
            confidence=int(100*(1-(result[1])/300))
            d_s=str(confidence)+'%Confidence it is XYZ'
        cv2.putText(image,d_s,(100,120),cv2.FONT_HERSHEY_COMPLEX,1,(250,120,255),2)

        if confidence>75:
             cv2.putText(image,"XYZ recognized ",(250,450),cv2.FONT_HERSHEY_COMPLEX,1,(0,0,255),2)
             cv2.imshow('Face cropper',image)
        else:
             cv2.putText(image,"XYZ not recognized ",(250,450),cv2.FONT_HERSHEY_COMPLEX,1,(255,0,255),2)
             cv2.imshow('Face cropper',image)
    except:
         cv2.putText(image,"face not found",(250,450),cv2.FONT_HERSHEY_COMPLEX,1,(255,0,0),2)
         cv2.imshow('Face cropper',image)
         pass

    if cv2.waitKey(1)==13:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-42d171653569> in <module>()
#       5
#       6 data_path='C:/Users/Akhil Roy/AppData/Local/Programs/Python/Python38/Facerecognition/Data/'
# ----> 7 onlyfiles=[f for f in listdir(data_path)if isfile(join(data_path,f))]
#       8
#       9 Training_data,Labels=[],[]
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/Akhil Roy/AppData/Local/Programs/Python/Python38/Facerecognition/Data/'
